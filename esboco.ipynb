# %% [markdown]
# # Análise de Dados

# %% [markdown]
# ### Carregando dados - Pandas

# %%
import pandas as pd

# %%
dados = pd.read_excel("vendas.xlsx")

# %%
dados
# Out:
#       id_pedido       data    loja          cidade          estado    regiao
# 0       PED1994 2020-01-01  Loja 4          Santos       São Paulo   Sudeste  \
# 1       PED2246 2020-01-01  Loja 6   Florianópolis  Santa Catarina       Sul
# 2       PED3876 2020-01-01  Loja 3  Rio de Janeiro  Rio de Janeiro   Sudeste
# 3       PED4352 2020-01-01  Loja 1       Fortaleza           Ceará  Nordeste
# 4       PED8633 2020-01-01  Loja 5       São Paulo       São Paulo   Sudeste
# ...         ...        ...     ...             ...             ...       ...
# 69995  PED67084 2022-12-31  Loja 6   Florianópolis  Santa Catarina       Sul
# 69996  PED67857 2022-12-31  Loja 3  Rio de Janeiro  Rio de Janeiro   Sudeste
# 69997  PED69171 2022-12-31  Loja 4          Santos       São Paulo   Sudeste
# 69998  PED69229 2022-12-31  Loja 4          Santos       São Paulo   Sudeste
# 69999  PED69356 2022-12-31  Loja 1       Fortaleza           Ceará  Nordeste
#
#       tamanho     local_consumo  preco forma_pagamento  ano_mes
# 0       300ml  Consumo no local      5        Dinheiro  2020-01
# 1       500ml  Consumo no local     11          Débito  2020-01
# 2       300ml          Delivery      7         Crédito  2020-01
# 3      1000ml  Consumo no local      7          Débito  2020-01
# 4       200ml          Delivery      9         Crédito  2020-01
# ...       ...               ...    ...             ...      ...
# 69995   500ml  Consumo no local     11         Crédito  2022-12
# 69996   200ml  Consumo no local      7             Pix  2022-12
# 69997   500ml  Consumo no local      5        Dinheiro  2022-12
# 69998   300ml  Consumo no local      9             Pix  2022-12
# 69999   300ml          Delivery      9             Pix  2022-12
#
# [70000 rows x 11 columns]

# %% [markdown]
# # Análises Exploratória

# %%
dados.head(10)
# Out:
#   id_pedido       data    loja          cidade          estado    regiao
# 0   PED1994 2020-01-01  Loja 4          Santos       São Paulo   Sudeste  \
# 1   PED2246 2020-01-01  Loja 6   Florianópolis  Santa Catarina       Sul
# 2   PED3876 2020-01-01  Loja 3  Rio de Janeiro  Rio de Janeiro   Sudeste
# 3   PED4352 2020-01-01  Loja 1       Fortaleza           Ceará  Nordeste
# 4   PED8633 2020-01-01  Loja 5       São Paulo       São Paulo   Sudeste
# 5  PED10668 2020-01-01  Loja 4          Santos       São Paulo   Sudeste
# 6  PED11326 2020-01-01  Loja 4          Santos       São Paulo   Sudeste
# 7  PED11327 2020-01-01  Loja 4          Santos       São Paulo   Sudeste
# 8  PED11506 2020-01-01  Loja 4          Santos       São Paulo   Sudeste
# 9  PED16937 2020-01-01  Loja 4          Santos       São Paulo   Sudeste
#
#   tamanho     local_consumo  preco forma_pagamento  ano_mes
# 0   300ml  Consumo no local      5        Dinheiro  2020-01
# 1   500ml  Consumo no local     11          Débito  2020-01
# 2   300ml          Delivery      7         Crédito  2020-01
# 3  1000ml  Consumo no local      7          Débito  2020-01
# 4   200ml          Delivery      9         Crédito  2020-01
# 5   500ml          Delivery      7         Crédito  2020-01
# 6   300ml          Delivery     11        Dinheiro  2020-01
# 7   200ml          Delivery      5             Pix  2020-01
# 8   300ml  Consumo no local      5          Débito  2020-01
# 9   700ml  Consumo no local     13        Dinheiro  2020-01

# %%
dados.tail(5)
# Out:
#       id_pedido       data    loja          cidade          estado    regiao
# 69995  PED67084 2022-12-31  Loja 6   Florianópolis  Santa Catarina       Sul  \
# 69996  PED67857 2022-12-31  Loja 3  Rio de Janeiro  Rio de Janeiro   Sudeste
# 69997  PED69171 2022-12-31  Loja 4          Santos       São Paulo   Sudeste
# 69998  PED69229 2022-12-31  Loja 4          Santos       São Paulo   Sudeste
# 69999  PED69356 2022-12-31  Loja 1       Fortaleza           Ceará  Nordeste
#
#       tamanho     local_consumo  preco forma_pagamento  ano_mes
# 69995   500ml  Consumo no local     11         Crédito  2022-12
# 69996   200ml  Consumo no local      7             Pix  2022-12
# 69997   500ml  Consumo no local      5        Dinheiro  2022-12
# 69998   300ml  Consumo no local      9             Pix  2022-12
# 69999   300ml          Delivery      9             Pix  2022-12

# %%
dados.shape
# Out:
# (70000, 11)

# %% [markdown]
# # Estatísticas

# %%
dados.describe()
# Out:
#                                 data         preco
# count                          70000  70000.000000
# mean   2021-10-01 20:36:10.697142784      8.355200
# min              2020-01-01 00:00:00      5.000000
# 25%              2021-01-01 00:00:00      7.000000
# 50%              2022-01-02 00:00:00      7.000000
# 75%              2022-07-02 00:00:00     11.000000
# max              2022-12-31 00:00:00     13.000000
# std                              NaN      2.653061

# %% [markdown]
# # Análises

# %%
dados
# Out:
#       id_pedido       data    loja          cidade          estado    regiao
# 0       PED1994 2020-01-01  Loja 4          Santos       São Paulo   Sudeste  \
# 1       PED2246 2020-01-01  Loja 6   Florianópolis  Santa Catarina       Sul
# 2       PED3876 2020-01-01  Loja 3  Rio de Janeiro  Rio de Janeiro   Sudeste
# 3       PED4352 2020-01-01  Loja 1       Fortaleza           Ceará  Nordeste
# 4       PED8633 2020-01-01  Loja 5       São Paulo       São Paulo   Sudeste
# ...         ...        ...     ...             ...             ...       ...
# 69995  PED67084 2022-12-31  Loja 6   Florianópolis  Santa Catarina       Sul
# 69996  PED67857 2022-12-31  Loja 3  Rio de Janeiro  Rio de Janeiro   Sudeste
# 69997  PED69171 2022-12-31  Loja 4          Santos       São Paulo   Sudeste
# 69998  PED69229 2022-12-31  Loja 4          Santos       São Paulo   Sudeste
# 69999  PED69356 2022-12-31  Loja 1       Fortaleza           Ceará  Nordeste
#
#       tamanho     local_consumo  preco forma_pagamento  ano_mes
# 0       300ml  Consumo no local      5        Dinheiro  2020-01
# 1       500ml  Consumo no local     11          Débito  2020-01
# 2       300ml          Delivery      7         Crédito  2020-01
# 3      1000ml  Consumo no local      7          Débito  2020-01
# 4       200ml          Delivery      9         Crédito  2020-01
# ...       ...               ...    ...             ...      ...
# 69995   500ml  Consumo no local     11         Crédito  2022-12
# 69996   200ml  Consumo no local      7             Pix  2022-12
# 69997   500ml  Consumo no local      5        Dinheiro  2022-12
# 69998   300ml  Consumo no local      9             Pix  2022-12
# 69999   300ml          Delivery      9             Pix  2022-12
#
# [70000 rows x 11 columns]

# %%
# total de pedidos por loja
dados.loja.value_counts()
# Out:
# loja
# Loja 4    13483
# Loja 6    13075
# Loja 1    12344
# Loja 5    12177
# Loja 3    10603
# Loja 2     8318
# Name: count, dtype: int64

# %%
# Totalde pedidos por forma de pagamento
dados.forma_pagamento.value_counts()
# Out:
# forma_pagamento
# Crédito     26063
# Débito      20427
# Dinheiro    14709
# Pix          8801
# Name: count, dtype: int64

# %% [markdown]
# # Faturamento

# %%
dados
# Out:
#       id_pedido       data    loja          cidade          estado    regiao
# 0       PED1994 2020-01-01  Loja 4          Santos       São Paulo   Sudeste  \
# 1       PED2246 2020-01-01  Loja 6   Florianópolis  Santa Catarina       Sul
# 2       PED3876 2020-01-01  Loja 3  Rio de Janeiro  Rio de Janeiro   Sudeste
# 3       PED4352 2020-01-01  Loja 1       Fortaleza           Ceará  Nordeste
# 4       PED8633 2020-01-01  Loja 5       São Paulo       São Paulo   Sudeste
# ...         ...        ...     ...             ...             ...       ...
# 69995  PED67084 2022-12-31  Loja 6   Florianópolis  Santa Catarina       Sul
# 69996  PED67857 2022-12-31  Loja 3  Rio de Janeiro  Rio de Janeiro   Sudeste
# 69997  PED69171 2022-12-31  Loja 4          Santos       São Paulo   Sudeste
# 69998  PED69229 2022-12-31  Loja 4          Santos       São Paulo   Sudeste
# 69999  PED69356 2022-12-31  Loja 1       Fortaleza           Ceará  Nordeste
#
#       tamanho     local_consumo  preco forma_pagamento  ano_mes
# 0       300ml  Consumo no local      5        Dinheiro  2020-01
# 1       500ml  Consumo no local     11          Débito  2020-01
# 2       300ml          Delivery      7         Crédito  2020-01
# 3      1000ml  Consumo no local      7          Débito  2020-01
# 4       200ml          Delivery      9         Crédito  2020-01
# ...       ...               ...    ...             ...      ...
# 69995   500ml  Consumo no local     11         Crédito  2022-12
# 69996   200ml  Consumo no local      7             Pix  2022-12
# 69997   500ml  Consumo no local      5        Dinheiro  2022-12
# 69998   300ml  Consumo no local      9             Pix  2022-12
# 69999   300ml          Delivery      9             Pix  2022-12
#
# [70000 rows x 11 columns]

# %%
dados['loja'].value_counts(normalize=True)
# Out:
# loja
# Loja 4    0.192614
# Loja 6    0.186786
# Loja 1    0.176343
# Loja 5    0.173957
# Loja 3    0.151471
# Loja 2    0.118829
# Name: proportion, dtype: float64

# %%
dados.groupby('loja').sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 dados.groupby('loja').sum()
#
# File c:\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:2263, in GroupBy.sum(self, numeric_only, min_count, engine, engine_kwargs)
#    2258 else:
#    2259     # If we are grouping on categoricals we want unobserved categories to
#    2260     # return zero, rather than the default of NaN which the reindexing in
#    2261     # _agg_general() returns. GH #31422
#    2262     with com.temp_setattr(self, "observed", True):
# -> 2263         result = self._agg_general(
#    2264             numeric_only=numeric_only,
#    2265             min_count=min_count,
#    2266             alias="sum",
#    2267             npfunc=np.sum,
#    2268         )
#    2270     return self._reindex_output(result, fill_value=0)
#
# File c:\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:1422, in GroupBy._agg_general(self, numeric_only, min_count, alias, npfunc)
#    1413 @final
#    1414 def _agg_general(
#    1415     self,
#    (...)
#    1420     npfunc: Callable,
#    1421 ):
# -> 1422     result = self._cython_agg_general(
#    1423         how=alias,
#    1424         alt=npfunc,
#    1425         numeric_only=numeric_only,
#    1426         min_count=min_count,
#    1427     )
#    1428     return result.__finalize__(self.obj, method="groupby")
#
# File c:\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:1507, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1503         result = self._agg_py_fallback(values, ndim=data.ndim, alt=alt)
#    1505     return result
# -> 1507 new_mgr = data.grouped_reduce(array_func)
#    1508 res = self._wrap_agged_manager(new_mgr)
#    1509 out = self._wrap_aggregated_output(res)
#
# File c:\Python311\Lib\site-packages\pandas\core\internals\managers.py:1506, in BlockManager.grouped_reduce(self, func)
#    1504             result_blocks = extend_blocks(applied, result_blocks)
#    1505     else:
# -> 1506         applied = blk.apply(func)
#    1507         result_blocks = extend_blocks(applied, result_blocks)
#    1509 if len(result_blocks) == 0:
#
# File c:\Python311\Lib\site-packages\pandas\core\internals\blocks.py:329, in Block.apply(self, func, **kwargs)
#     323 @final
#     324 def apply(self, func, **kwargs) -> list[Block]:
#     325     """
#     326     apply the function to my values; return a block if we are not
#     327     one
#     328     """
# --> 329     result = func(self.values, **kwargs)
#     331     return self._split_op_result(result)
#
# File c:\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:1490, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1488 def array_func(values: ArrayLike) -> ArrayLike:
#    1489     try:
# -> 1490         result = self.grouper._cython_operation(
#    1491             "aggregate",
#    1492             values,
#    1493             how,
#    1494             axis=data.ndim - 1,
#    1495             min_count=min_count,
#    1496             **kwargs,
#    1497         )
#    1498     except NotImplementedError:
#    1499         # generally if we have numeric_only=False
#    1500         # and non-applicable functions
#    1501         # try to python agg
#    1502         # TODO: shouldn't min_count matter?
#    1503         result = self._agg_py_fallback(values, ndim=data.ndim, alt=alt)
#
# File c:\Python311\Lib\site-packages\pandas\core\groupby\ops.py:959, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     957 ids, _, _ = self.group_info
#     958 ngroups = self.ngroups
# --> 959 return cy_op.cython_operation(
#     960     values=values,
#     961     axis=axis,
#     962     min_count=min_count,
#     963     comp_ids=ids,
#     964     ngroups=ngroups,
#     965     **kwargs,
#     966 )
#
# File c:\Python311\Lib\site-packages\pandas\core\groupby\ops.py:645, in WrappedCythonOp.cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     641 is_numeric = is_numeric_dtype(dtype)
#     643 # can we do this operation with our cython functions
#     644 # if not raise NotImplementedError
# --> 645 self._disallow_invalid_ops(dtype, is_numeric)
#     647 if not isinstance(values, np.ndarray):
#     648     # i.e. ExtensionArray
#     649     return self._ea_wrap_cython_operation(
#     650         values,
#     651         min_count=min_count,
#    (...)
#     654         **kwargs,
#     655     )
#
# File c:\Python311\Lib\site-packages\pandas\core\groupby\ops.py:257, in WrappedCythonOp._disallow_invalid_ops(self, dtype, is_numeric)
#     254 elif is_datetime64_any_dtype(dtype):
#     255     # Adding/multiplying datetimes is not valid
#     256     if how in ["sum", "prod", "cumsum", "cumprod"]:
# --> 257         raise TypeError(f"datetime64 type does not support {how} operations")
#     258 elif is_period_dtype(dtype):
#     259     # Adding/multiplying Periods is not valid
#     260     if how in ["sum", "prod", "cumsum", "cumprod"]:
#
# TypeError: datetime64 type does not support sum operations
