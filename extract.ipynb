# %%
import openpyxl as xl
import pdfplumber
import os

# %%
# buscar os arquivos pdf

for arquivo in os.listdir('pdfs'):
   
    if arquivo.endswith('.pdf'):
        
        excel = xl.load_workbook('Base de Dados Inspeções.xlsx')
        aba = excel.active
        linha_inicio = len(aba['A']) + 1
        pdf = pdfplumber.open(f'pdfs\\{arquivo}')
        pagina = pdf.pages[0]
        
        dados = pagina.extract_table()
     
        for indice, dado in enumerate(dados[1:], start = linha_inicio):
            if dado[0] == '':
                pass
            else:
                aba.cell(row= indice, column= 1).value = dado[0]
                aba.cell(row= indice, column= 2).value = dado[1]
                aba.cell(row= indice, column= 3).value = dado[2]
                aba.cell(row= indice, column= 4).value = dado[3]
                aba.cell(row= indice, column= 5).value = dado[4]
                print(indice, dado)

        pdf.close()
        excel.save('Base de Dados Inspeções.xlsx')
        excel.close()

        
    else:
        pass
# Out:
# 2 ['01/01/2022', 'Empresa A', 'Recursos Humanos', 'Sala 1', 'Aprovado']
# 3 ['01/01/2022', 'Empresa A', 'Recursos Humanos', 'Sala 2', 'Aprovado']
# 4 ['01/01/2022', 'Empresa A', 'Recursos Humanos', 'Sala3', 'Aprovado']
# 5 ['01/01/2022', 'Empresa A', 'Recursos Humanos', 'Sala 4', 'Aprovado']
# 6 ['01/01/2022', 'Empresa A', 'Recursos Humanos', 'Banheiro', 'Reprovado']
# 7 ['01/01/2022', 'Empresa A', 'Recursos Humanos', 'Refeitório', 'Aprovado']
# 8 ['01/01/2022', 'Empresa A', 'Recursos Humanos', 'Sala 5', 'Aprovado']
# 9 ['02/02/2022', 'Empresa A', 'Tecnologia da Informação', 'Sala 1', 'Aprovado']
# 10 ['02/02/2022', 'Empresa A', 'Tecnologia da Informação', 'Sala 2', 'Aprovado']
# 11 ['02/02/2022', 'Empresa A', 'Tecnologia da Informação', 'Sala 3', 'Aprovado']
# 12 ['02/02/2022', 'Empresa A', 'Tecnologia da Informação', 'Banheiro', 'Reprovado']
# 13 ['02/02/2022', 'Empresa A', 'Tecnologia da Informação', 'Refeitório', 'Aprovado']
# 14 ['03/02/2022', 'Empresa A', 'Galpão I', 'Aréa descarga', 'Aprovado']
# 15 ['03/02/2022', 'Empresa A', 'Galpão I', 'Sala 1', 'Aprovado']
# 16 ['03/02/2022', 'Empresa A', 'Galpão I', 'Sala 2', 'Aprovado']
# 17 ['03/02/2022', 'Empresa A', 'Galpão I', 'Sala 3', 'Aprovado']
# 18 ['03/02/2022', 'Empresa A', 'Galpão I', 'Área carga', 'Aprovado']
# 19 ['03/02/2022', 'Empresa A', 'Galpão I', 'Refeitório', 'Aprovado']
# 20 ['03/02/2022', 'Empresa A', 'Galpão I', 'Banheiro', 'Reprovado']
# 21 ['01/03/2022', 'Empresa B', 'Recursos Humanos', 'Sala 1', 'Aprovado']
# 22 ['01/03/2022', 'Empresa B', 'Recursos Humanos', 'Sala 2', 'Aprovado']
# 23 ['01/03/2022', 'Empresa B', 'Recursos Humanos', 'Sala3', 'Aprovado']
# 24 ['01/03/2022', 'Empresa B', 'Recursos Humanos', 'Sala 4', 'Aprovado']
# 25 ['01/03/2022', 'Empresa B', 'Recursos Humanos', 'Banheiro', 'Reprovado']
# 26 ['01/03/2022', 'Empresa B', 'Recursos Humanos', 'Refeitório', 'Aprovado']
# 27 ['01/03/2022', 'Empresa B', 'Recursos Humanos', 'Sala 5', 'Aprovado']
# 28 ['02/04/2022', 'Empresa B', 'Tecnologia da Informação', 'Sala 1', 'Aprovado']
# 29 ['02/04/2022', 'Empresa B', 'Tecnologia da Informação', 'Sala 2', 'Aprovado']
# 30 ['02/04/2022', 'Empresa B', 'Tecnologia da Informação', 'Sala 3', 'Aprovado']
# 31 ['02/04/2022', 'Empresa B', 'Tecnologia da Informação', 'Banheiro', 'Reprovado']
# 32 ['02/04/2022', 'Empresa B', 'Tecnologia da Informação', 'Refeitório', 'Aprovado']
# 33 ['03/04/2022', 'Empresa B', 'Galpão I', 'Aréa descarga', 'Aprovado']
# 34 ['03/04/2022', 'Empresa B', 'Galpão I', 'Sala 1', 'Aprovado']
# 35 ['03/04/2022', 'Empresa B', 'Galpão I', 'Sala 2', 'Aprovado']
# 36 ['03/04/2022', 'Empresa B', 'Galpão I', 'Sala 3', 'Aprovado']
# 37 ['03/04/2022', 'Empresa B', 'Galpão I', 'Área carga', 'Aprovado']
# 38 ['03/04/2022', 'Empresa B', 'Galpão I', 'Refeitório', 'Aprovado']
# 39 ['03/04/2022', 'Empresa B', 'Galpão I', 'Banheiro', 'Reprovado']
# 40 ['05/04/2022', 'Empresa B', 'Financeiro', 'Sala 1', 'Aprovado']
# 41 ['05/04/2022', 'Empresa B', 'Financeiro', 'Sala 2', 'Aprovado']
# 42 ['05/04/2022', 'Empresa B', 'Financeiro', 'Sala 3', 'Aprovado']
# 43 ['05/04/2022', 'Empresa B', 'Financeiro', 'Sala 4', 'Aprovado']
# 44 ['05/04/2022', 'Empresa B', 'Financeiro', 'Sala 5', 'Aprovado']
# 45 ['05/04/2022', 'Empresa B', 'Financeiro', 'Sala 6', 'Aprovado']
# 46 ['05/04/2022', 'Empresa B', 'Financeiro', 'Auditório', 'Aprovado']
# 47 ['05/04/2022', 'Empresa B', 'Financeiro', 'Refeitório', 'Reprovado']
# 48 ['05/06/2022', 'Empresa C', 'Recursos Humanos', 'Sala 1', 'Aprovado']
# 49 ['05/06/2022', 'Empresa C', 'Recursos Humanos', 'Sala 2', 'Aprovado']
# 50 ['05/06/2022', 'Empresa C', 'Recursos Humanos', 'Sala3', 'Aprovado']
# 51 ['05/06/2022', 'Empresa C', 'Recursos Humanos', 'Sala 4', 'Aprovado']
# 52 ['05/06/2022', 'Empresa C', 'Recursos Humanos', 'Banheiro', 'Aprovado']
# 53 ['05/06/2022', 'Empresa C', 'Recursos Humanos', 'Refeitório', 'Aprovado']
# 54 ['05/06/2022', 'Empresa C', 'Recursos Humanos', 'Sala 5', 'Aprovado']
# 55 ['06/06/2022', 'Empresa C', 'Tecnologia da Informação', 'Sala 1', 'Aprovado']
# 56 ['06/06/2022', 'Empresa C', 'Tecnologia da Informação', 'Sala 2', 'Aprovado']
# 57 ['06/06/2022', 'Empresa C', 'Tecnologia da Informação', 'Sala 3', 'Aprovado']
# 58 ['06/06/2022', 'Empresa C', 'Tecnologia da Informação', 'Banheiro', 'Aprovado']
# 59 ['06/06/2022', 'Empresa C', 'Tecnologia da Informação', 'Refeitório', 'Aprovado']
# 60 ['07/07/2022', 'Empresa D', 'Recursos Humanos', 'Sala 1', 'Aprovado']
# 61 ['07/07/2022', 'Empresa D', 'Recursos Humanos', 'Sala 2', 'Aprovado']
# 62 ['07/07/2022', 'Empresa D', 'Recursos Humanos', 'Sala3', 'Aprovado']
# 63 ['07/07/2022', 'Empresa D', 'Recursos Humanos', 'Sala 4', 'Aprovado']
# 64 ['07/07/2022', 'Empresa D', 'Recursos Humanos', 'Banheiro', 'Aprovado']
# 65 ['07/07/2022', 'Empresa D', 'Recursos Humanos', 'Refeitório', 'Aprovado']
# 66 ['07/07/2022', 'Empresa D', 'Recursos Humanos', 'Sala 5', 'Aprovado']
# 67 ['08/07/2022', 'Empresa D', 'Tecnologia da Informação', 'Sala 1', 'Aprovado']
# 68 ['08/07/2022', 'Empresa D', 'Tecnologia da Informação', 'Sala 2', 'Aprovado']
# 69 ['08/07/2022', 'Empresa D', 'Tecnologia da Informação', 'Sala 3', 'Aprovado']
# 70 ['08/07/2022', 'Empresa D', 'Tecnologia da Informação', 'Banheiro', 'Aprovado']
# 71 ['08/07/2022', 'Empresa D', 'Tecnologia da Informação', 'Refeitório', 'Aprovado']
# 72 ['09/07/2022', 'Empresa D', 'Suprimentos', 'Sala 1', 'Aprovado']
# 73 ['09/07/2022', 'Empresa D', 'Suprimentos', 'Sala 2', 'Aprovado']
# 74 ['09/07/2022', 'Empresa D', 'Suprimentos', 'Sala 3', 'Reprovado']
# 75 ['09/07/2022', 'Empresa D', 'Suprimentos', 'Auditório', 'Aprovado']
# 76 ['09/07/2022', 'Empresa D', 'Suprimentos', 'Refeitório', 'Reprovado']
# 77 ['09/07/2022', 'Empresa D', 'Suprimentos', 'Banheiro', 'Reprovado']
